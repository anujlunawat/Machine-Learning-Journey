# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Input, Dense, Flatten
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime
from pathlib import Path
from time import strftime

# %%
def get_run_logdir(root_logdir="logs/fit"):
 return Path(root_logdir) / strftime("run_%Y_%m_%d_%H_%M_%S")

# %%
data = keras.datasets.fashion_mnist.load_data()

# %%
(X_train_full, y_train_full), (X_test, y_test) = data

X_train, y_train = X_train_full[:-5000], y_train_full[:-5000]
X_valid, y_valid = X_train_full[-5000:], y_train_full[-5000:]

# %%
X_train, X_valid, X_test = X_train/255., X_valid/255., X_test/255.

# %%
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat","Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %%
# keras.backend.clear_session()

# %%
tf.random.set_seed(42)

model = Sequential([
    Input(shape=X_train.shape[1:]),
    Flatten(),
    Dense(300, activation="relu"),
    Dense(100, activation='relu'),
    Dense(10, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 300)            │       235,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 100)            │        30,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         1,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 266,610 (1.02 MB)
#  Trainable params: 266,610 (1.02 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = keras.optimizers.SGD(1e-3)

# %%
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer)

# %%
log_dir = get_run_logdir()
tensorboard_cb = keras.callbacks.TensorBoard(log_dir, histogram_freq=1, profile_batch=(100, 200))

# %%
history = model.fit(X_train, y_train, epochs=5, validation_split=.2, callbacks=[tensorboard_cb])
# Out:
# Epoch 1/5
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.5947 - val_loss: 0.5856
# Epoch 2/5
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5664 - val_loss: 0.5636
# Epoch 3/5
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5448 - val_loss: 0.5465
# Epoch 4/5
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.5278 - val_loss: 0.5328
# Epoch 5/5
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.5139 - val_loss: 0.5214

# %%
# %load_ext tensorboard
# %tensorboard --logdir=./logs/fit
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 24072), started 0:15:27 ago. (Use '!kill 24072' to kill it.)
#       <iframe id="tensorboard-frame-f5cf2492613e6be8" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-f5cf2492613e6be8");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --logdir logs --port 6006

# %%
optimizer.learning_rate = 2e-3

# %%
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer)

# %%
log_dir = get_run_logdir()
tensorboard_cb = keras.callbacks.TensorBoard(log_dir, histogram_freq=1, profile_batch=(100, 200), )

# %%
history2 = model.fit(X_train, y_train, epochs=30, validation_split=.2, callbacks=tensorboard_cb)
# Out:
# Epoch 1/30
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.3281 - val_loss: 0.3690
# Epoch 2/30
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.3262 - val_loss: 0.3680
# Epoch 3/30
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.3244 - val_loss: 0.3669
# Epoch 4/30
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.3226 - val_loss: 0.3658
# Epoch 5/30
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.3209 - val_loss: 0.3648
# Epoch 6/30
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.3192 - val_loss: 0.3639
# Epoch 7/30
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.3175 - val_loss: 0.3630
# Epoch 8/30
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.3158 - val_loss: 0.3620
# Epoch 9/30
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.3141 - val_loss: 0.3608
# Epoch 10/30
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.3125 - val_loss: 0.3600
# Epoch 11/30
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.3108 - val_loss: 0.3591
# Epoch 12/30
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.3093 - val_loss: 0.3582
# Epoch 13/30
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.3077 - val_loss: 0.3574
# Epoch 14/30
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.3061 - val_loss: 0.3565
# Epoch 15/30
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.3045 - val_loss: 0.3558
# Epoch 16/30
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.3029 - val_loss: 0.3553
# Epoch 17/30
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.3014 - val_loss: 0.3545
# Epoch 18/30
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2999 - val_loss: 0.3537
# Epoch 19/30
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2983 - val_loss: 0.3529
# Epoch 20/30
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2969 - val_loss: 0.3521
# Epoch 21/30
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2954 - val_loss: 0.3514
# Epoch 22/30
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2939 - val_loss: 0.3507
# Epoch 23/30
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2925 - val_loss: 0.3500
# Epoch 24/30
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2910 - val_loss: 0.3494
# Epoch 25/30
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2896 - val_loss: 0.3488
# Epoch 26/30
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2882 - val_loss: 0.3481
# Epoch 27/30
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.2868 - val_loss: 0.3474
# Epoch 28/30
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2854 - val_loss: 0.3469
# Epoch 29/30
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2840 - val_loss: 0.3462
# Epoch 30/30
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.2826 - val_loss: 0.3456
